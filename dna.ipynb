# %% [markdown]
# <a href="https://colab.research.google.com/github/JohnWentler/systemsoftwarefilewin10/blob/main/dna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
import time
from openpyxl import load_workbook

# %%
csv1 = r'/content/drive/MyDrive/DNA/Input_Reference_File_1.csv'
csv2 = r'/content/drive/MyDrive/DNA/Input_Reference_File_2.csv'

# %%
i = pd.read_csv(csv1,skiprows=6,usecols=['Ch 1 Displacement ','Ch 1 Force '])

# %%
j = pd.read_csv(csv2,skiprows=6,usecols=['Ch 1 Displacement ','Ch 1 Force '])

# %%
i.head(10)
# Out:
#      Ch 1 Displacement           Ch 1 Force
# 0                    mm                   kN
# 1  0.000143051153145279  -0.0360655364990234
# 2   0.00177025799530384  -0.0388465461730957
# 3  0.000715255737304688  -0.0308821640014648
# 4   0.00110864641555963  -0.0268653011322021
# 5   0.00190436844604847  -0.0294460487365723
# 6   0.00251233586823219  -0.0352873611450195
# 7   4.4703483581543E-05  -0.0358311576843262
# 8  0.000277161603889908  -0.0267332248687744
# 9   0.00176131720763806  -0.0393835487365723

# %%
j.head(10)
# Out:
#   Ch 1 Displacement      Ch 1 Force
# 0                 mm              kN
# 1            0.41243   -0.0360655365
# 2       0.4122354243   -0.0360655365
# 3           0.344124   -0.0360655365
# 4            0.42553   -0.0360655365
# 5          0.1234456   -0.0360655365
# 6         0.31224542   -0.0360655365
# 7     11111111111111   -0.0360655365
# 8    0.0002771616039  -0.02673322487
# 9     0.001761317208  -0.03938354874

# %%
# s = pd.read_csv("/content/drive/MyDrive/DNA/Input_Reference_File.csv",encoding="latin-1",delimiter="\t")

# %%
column_list = i.columns.tolist()+j.columns.tolist()
column_list
# Out:
# ['Ch 1 Displacement ', 'Ch 1 Force ', 'Ch 1 Displacement ', 'Ch 1 Force ']

# %%
# h = i[["Ch 1 Displacement ","Ch 1 Force "]]
# h.head(10)

# %%
# df_output = h.rename(columns={"Ch 1 Displacement":"dis","Ch 1 Force":"force"})
# df_output.head(10)

i.rename(columns={"Ch 1 Displacement": "Displacement", "Ch 1 Force": "force"})
j.rename(columns={"Ch 1 Displacement": "Displacement", "Ch 1 Force": "force"})

data = pd.concat([i,j], ignore_index=False)
data = pd.concat([i,j], axis=1)

multi_indecies = pd.MultiIndex.from_tuples([('Control', 'Displacement'), ('Control', 'Force'), ('Title','Displacement'), ('Title','Force')])
data.columns = multi_indecies
# data.reset_index(drop=True, inplace=False)
data.head(10)
# Out:
#                 Control                                 Title
#            Displacement                Force     Displacement           Force
# 0                    mm                   kN               mm              kN
# 1  0.000143051153145279  -0.0360655364990234          0.41243   -0.0360655365
# 2   0.00177025799530384  -0.0388465461730957     0.4122354243   -0.0360655365
# 3  0.000715255737304688  -0.0308821640014648         0.344124   -0.0360655365
# 4   0.00110864641555963  -0.0268653011322021          0.42553   -0.0360655365
# 5   0.00190436844604847  -0.0294460487365723        0.1234456   -0.0360655365
# 6   0.00251233586823219  -0.0352873611450195       0.31224542   -0.0360655365
# 7   4.4703483581543E-05  -0.0358311576843262   11111111111111   -0.0360655365
# 8  0.000277161603889908  -0.0267332248687744  0.0002771616039  -0.02673322487
# 9   0.00176131720763806  -0.0393835487365723   0.001761317208  -0.03938354874

# %%
path = '/content/drive/MyDrive/DNA/output_1_2.xlsx'
data.to_excel(path)

# %%
import pandas as pd
from openpyxl import load_workbook
from openpyxl.styles import Font

# ... (Your code to create the 'data' DataFrame and save it to Excel)

path = '/content/drive/MyDrive/DNA/output_1_2.xlsx'

# Load the workbook
wb = load_workbook(path)
ws = wb.active  # Select the active worksheet

# Delete the first column (column 'A')
ws.delete_cols(1)

# Style the first row (now the second row after deletion)
for cell in ws[1]:
    cell.font = Font(size=20, bold=True)

# Save the modified workbook
wb.save(path)

# %%
# print(data.columns)
print(data)
# Out:
#                     Control                              Title
#                Displacement                Force  Displacement          Force
# 0                        mm                   kN            mm             kN
# 1      0.000143051153145279  -0.0360655364990234       0.41243  -0.0360655365
# 2       0.00177025799530384  -0.0388465461730957  0.4122354243  -0.0360655365
# 3      0.000715255737304688  -0.0308821640014648      0.344124  -0.0360655365
# 4       0.00110864641555963  -0.0268653011322021       0.42553  -0.0360655365
# ...                     ...                  ...           ...            ...
# 11360     -1.51053967420012   -0.176333160400391  -1.510539674  -0.1763331604
# 11361     -1.51032512076199   -0.175868347167969  -1.510325121  -0.1758683472
# 11362     -1.50908227078617   -0.180253173828125  -1.509082271  -0.1802531738
# 11363     -1.50834023952484   -0.173075500488281   -1.50834024  -0.1730755005
# ...

# %%
# print(df_output.columns)

# %%
# multi_index = pd.MultiIndex.from_tuples([('Control', 'Displacement'), ('Control', 'Force')])
# df_output.columns = multi_index  # Assign MultiIndex directly


# df_output.head(10)
# Out:
#                                   Control  \
#                              Displacement
# 0                                 mm---mm
# 1          0.000143051153145279---0.41243
# 2      0.00177025799530384---0.4122354243
# 3         0.000715255737304688---0.344124
# 4           0.00110864641555963---0.42553
# 5         0.00190436844604847---0.1234456
# 6        0.00251233586823219---0.31224542
# 7    4.4703483581543E-05---11111111111111
# 8  0.000277161603889908---0.0002771616039
# 9    0.00176131720763806---0.001761317208
#
#
#                                   Force
# 0                               kN---kN
# 1   -0.0360655364990234----0.0360655365
# 2   -0.0388465461730957----0.0360655365
# 3   -0.0308821640014648----0.0360655365
# 4   -0.0268653011322021----0.0360655365
# 5   -0.0294460487365723----0.0360655365
# 6   -0.0352873611450195----0.0360655365
# 7   -0.0358311576843262----0.0360655365
# 8  -0.0267332248687744----0.02673322487
# 9  -0.0393835487365723----0.03938354874
